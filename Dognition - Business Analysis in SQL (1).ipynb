# %% [markdown]
# Analysis questions addressed in this notebook:
#     1. What times (months, weekdays, hour) do users complete the tests?
#     2. What are the geographical locations where most users live? What times do US users tend to complete tests?
#     3. Do certain breeds of dogs complete more tests than others?
#     4. Are DNA-tested dogs or neutered dogs more likely to complete more tests?
#
# Since the database is not locally accessible, the analyses in this notebook is restricted to SQL. For an analysis using a combination of Python packages, SQL queries and Tableau charts, see "Dognition:User Retention."

# %%
# %load_ext sql
# %sql mysql://studentuser:studentpw@localhost/dognitiondb
# %sql USE dognitiondb
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 0 rows affected.
# []

# %% [markdown]
# In each months, how many tests do users complete and which tests are they? Exclude the dogs that show abnormalities from earlier investigation (dogs that are not test accounts, dogs that do not have null ID, dogs that do not have an 'exclude' mark).

# %%
# %%sql
# SELECT COUNT(cleaned_tests.created_at) AS completed_tests,
# MONTH(cleaned_tests.created_at) AS month_n, cleaned_tests.test_name
# FROM
# (SELECT c.created_at, c.test_name, d.dog_guid
# FROM complete_tests c LEFT JOIN dogs d ON c.dog_guid=d.dog_guid
# WHERE (d.dog_guid NOT IN
#     (SELECT DISTINCT(dog_guid) FROM dogs
#      WHERE (weight=190 AND breed='Shih Tzu') OR exclude=1)
#     AND c.dog_guid IS NOT NULL)) AS cleaned_tests
# GROUP BY MONTH(cleaned_tests.created_at), cleaned_tests.test_name
# ORDER BY MONTH(cleaned_tests.created_at)
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 480 rows affected.
# [(24, 1, '1 vs 1 Game'),
#  (33, 1, '3 vs 1 Game'),
#  (56, 1, '5 vs 1 Game'),
#  (586, 1, 'Arm Pointing'),
#  (418, 1, 'Cover Your Eyes'),
#  (328, 1, 'Delayed Cup Game'),
#  (2, 1, 'Different Perspective'),
#  (6, 1, 'Expression Game'),
#  (594, 1, 'Eye Contact Game'),
#  (676, 1, 'Eye Contact Warm-up'),
#  (475, 1, 'Foot Pointing'),
#  (45, 1, 'Impossible Task Game'),
#  (46, 1, 'Impossible Task Warm-up'),
#  (379, 1, 'Inferential Reasoning Game'),
#  (392, 1, 'Inferential Reasoning Warm-up'),
#  (427, 1, 'Memory versus Pointing'),
#  (428, 1, 'Memory versus Smell'),
#  (54, 1, 'Navigation Game'),
#  (55, 1, 'Navigation Learning'),
#  (58, 1, 'Navigation Warm-up'),
#  (34, 1, 'Numerosity Warm-Up'),
#  (440, 1, 'One Cup Warm-up'),
#  (294, 1, 'Physical Reasoning Game'),
#  (354, 1, 'Physical Reasoning Warm-up'),
#  (7, 1, 'Self Control Game'),
#  (2, 1, 'Shaker Game'),
#  (2, 1, 'Shaker Warm-Up'),
#  (1, 1, 'Shared Perspective'),
#  (16, 1, 'Slide'),
#  (13, 1, 'Smell Game'),
#  (10, 1, 'Stair Game'),
#  (14, 1, 'Switch'),
#  (592, 1, 'Treat Warm-up'),
#  (427, 1, 'Turn Your Back'),
#  (447, 1, 'Two Cup Warm-up'),
#  (66, 1, 'Warm-up'),
#  (553, 1, 'Watching'),
#  (412, 1, 'Watching - Part 2'),
#  (798, 1, 'Yawn Game'),
#  (804, 1, 'Yawn Warm-up'),
#  (25, 2, '1 vs 1 Game'),
#  (25, 2, '3 vs 1 Game'),
#  (49, 2, '5 vs 1 Game'),
#  (446, 2, 'Arm Pointing'),
#  (330, 2, 'Cover Your Eyes'),
#  (281, 2, 'Delayed Cup Game'),
#  (3, 2, 'Different Perspective'),
#  (9, 2, 'Expression Game'),
#  (509, 2, 'Eye Contact Game'),
#  (558, 2, 'Eye Contact Warm-up'),
#  (383, 2, 'Foot Pointing'),
#  (43, 2, 'Impossible Task Game'),
#  (44, 2, 'Impossible Task Warm-up'),
#  (257, 2, 'Inferential Reasoning Game'),
#  (264, 2, 'Inferential Reasoning Warm-up'),
#  (355, 2, 'Memory versus Pointing'),
#  (334, 2, 'Memory versus Smell'),
#  (35, 2, 'Navigation Game'),
#  (37, 2, 'Navigation Learning'),
#  (37, 2, 'Navigation Warm-up'),
#  (25, 2, 'Numerosity Warm-Up'),
#  (345, 2, 'One Cup Warm-up'),
#  (217, 2, 'Physical Reasoning Game'),
#  (253, 2, 'Physical Reasoning Warm-up'),
#  (8, 2, 'Self Control Game'),
#  (8, 2, 'Shaker Game'),
#  (9, 2, 'Shaker Warm-Up'),
#  (3, 2, 'Shared Perspective'),
#  (10, 2, 'Slide'),
#  (16, 2, 'Smell Game'),
#  (8, 2, 'Stair Game'),
#  (10, 2, 'Switch'),
#  (444, 2, 'Treat Warm-up'),
#  (329, 2, 'Turn Your Back'),
#  (344, 2, 'Two Cup Warm-up'),
#  (70, 2, 'Warm-up'),
#  (398, 2, 'Watching'),
#  (328, 2, 'Watching - Part 2'),
#  (648, 2, 'Yawn Game'),
#  (650, 2, 'Yawn Warm-up'),
#  (19, 3, '1 vs 1 Game'),
#  (28, 3, '3 vs 1 Game'),
#  (48, 3, '5 vs 1 Game'),
#  (443, 3, 'Arm Pointing'),
#  (361, 3, 'Cover Your Eyes'),
#  (299, 3, 'Delayed Cup Game'),
#  (4, 3, 'Different Perspective'),
#  (10, 3, 'Expression Game'),
#  (526, 3, 'Eye Contact Game'),
#  (552, 3, 'Eye Contact Warm-up'),
#  (414, 3, 'Foot Pointing'),
#  (33, 3, 'Impossible Task Game'),
#  (34, 3, 'Impossible Task Warm-up'),
#  (287, 3, 'Inferential Reasoning Game'),
#  (304, 3, 'Inferential Reasoning Warm-up'),
#  (326, 3, 'Memory versus Pointing'),
#  (323, 3, 'Memory versus Smell'),
#  (39, 3, 'Navigation Game'),
#  (39, 3, 'Navigation Learning'),
#  (42, 3, 'Navigation Warm-up'),
#  (29, 3, 'Numerosity Warm-Up'),
#  (335, 3, 'One Cup Warm-up'),
#  (272, 3, 'Physical Reasoning Game'),
#  (285, 3, 'Physical Reasoning Warm-up'),
#  (10, 3, 'Self Control Game'),
#  (6, 3, 'Shaker Game'),
#  (6, 3, 'Shaker Warm-Up'),
#  (3, 3, 'Shared Perspective'),
#  (14, 3, 'Slide'),
#  (14, 3, 'Smell Game'),
#  (5, 3, 'Stair Game'),
#  (12, 3, 'Switch'),
#  (448, 3, 'Treat Warm-up'),
#  (361, 3, 'Turn Your Back'),
#  (335, 3, 'Two Cup Warm-up'),
#  (69, 3, 'Warm-Up'),
#  (409, 3, 'Watching'),
#  (352, 3, 'Watching - Part 2'),
#  (614, 3, 'Yawn Game'),
#  (629, 3, 'Yawn Warm-up'),
#  (12, 4, '1 vs 1 Game'),
#  (16, 4, '3 vs 1 Game'),
#  (29, 4, '5 vs 1 Game'),
#  (348, 4, 'Arm Pointing'),
#  (255, 4, 'Cover Your Eyes'),
#  (216, 4, 'Delayed Cup Game'),
#  (8, 4, 'Different Perspective'),
#  (10, 4, 'Expression Game'),
#  (416, 4, 'Eye Contact Game'),
#  (423, 4, 'Eye Contact Warm-up'),
#  (307, 4, 'Foot Pointing'),
#  (38, 4, 'Impossible Task Game'),
#  (37, 4, 'Impossible Task Warm-up'),
#  (220, 4, 'Inferential Reasoning Game'),
#  (222, 4, 'Inferential Reasoning Warm-up'),
#  (253, 4, 'Memory versus Pointing'),
#  (233, 4, 'Memory versus Smell'),
#  (31, 4, 'Navigation Game'),
#  (34, 4, 'Navigation Learning'),
#  (34, 4, 'Navigation Warm-up'),
#  (17, 4, 'Numerosity Warm-Up'),
#  (265, 4, 'One Cup Warm-up'),
#  (192, 4, 'Physical Reasoning Game'),
#  (211, 4, 'Physical Reasoning Warm-up'),
#  (9, 4, 'Self Control Game'),
#  (3, 4, 'Shaker Game'),
#  (3, 4, 'Shaker Warm-Up'),
#  (8, 4, 'Shared Perspective'),
#  (10, 4, 'Slide'),
#  (6, 4, 'Smell Game'),
#  (3, 4, 'Stair Game'),
#  (10, 4, 'Switch'),
#  (359, 4, 'Treat Warm-up'),
#  (262, 4, 'Turn Your Back'),
#  (259, 4, 'Two Cup Warm-up'),
#  (52, 4, 'Warm-Up'),
#  (288, 4, 'Watching'),
#  (246, 4, 'Watching - Part 2'),
#  (492, 4, 'Yawn Game'),
#  (505, 4, 'Yawn Warm-up'),
#  (12, 5, '1 vs 1 Game'),
#  (29, 5, '3 vs 1 Game'),
#  (42, 5, '5 vs 1 Game'),
#  (1061, 5, 'Arm Pointing'),
#  (680, 5, 'Cover Your Eyes'),
#  (469, 5, 'Delayed Cup Game'),
#  (9, 5, 'Different Perspective'),
#  (8, 5, 'Expression Game'),
#  (1326, 5, 'Eye Contact Game'),
#  (1545, 5, 'Eye Contact Warm-up'),
#  (847, 5, 'Foot Pointing'),
#  (40, 5, 'Impossible Task Game'),
#  (40, 5, 'Impossible Task Warm-up'),
#  (459, 5, 'Inferential Reasoning Game'),
#  (474, 5, 'Inferential Reasoning Warm-up'),
#  (627, 5, 'Memory versus Pointing'),
#  (583, 5, 'Memory versus Smell'),
#  (321, 5, 'Navigation Game'),
#  (429, 5, 'Navigation Learning'),
#  (606, 5, 'Navigation Warm-up'),
#  (30, 5, 'Numerosity Warm-Up'),
#  (669, 5, 'One Cup Warm-up'),
#  (369, 5, 'Physical Reasoning Game'),
#  (440, 5, 'Physical Reasoning Warm-up'),
#  (9, 5, 'Self Control Game'),
#  (10, 5, 'Shaker Game'),
#  (10, 5, 'Shaker Warm-Up'),
#  (8, 5, 'Shared Perspective'),
#  (16, 5, 'Slide'),
#  (19, 5, 'Smell Game'),
#  (10, 5, 'Stair Game'),
#  (14, 5, 'Switch'),
#  (1091, 5, 'Treat Warm-up'),
#  (696, 5, 'Turn Your Back'),
#  (661, 5, 'Two Cup Warm-up'),
#  (68, 5, 'Warm-Up'),
#  (882, 5, 'Watching'),
#  (660, 5, 'Watching - Part 2'),
#  (1954, 5, 'Yawn Game'),
#  (2029, 5, 'Yawn Warm-up'),
#  (12, 6, '1 vs 1 Game'),
#  (36, 6, '3 vs 1 Game'),
#  (49, 6, '5 vs 1 Game'),
#  (1340, 6, 'Arm Pointing'),
#  (700, 6, 'Cover Your Eyes'),
#  (471, 6, 'Delayed Cup Game'),
#  (8, 6, 'Different Perspective'),
#  (9, 6, 'Expression Game'),
#  (1723, 6, 'Eye Contact Game'),
#  (2055, 6, 'Eye Contact Warm-up'),
#  (1044, 6, 'Foot Pointing'),
#  (49, 6, 'Impossible Task Game'),
#  (48, 6, 'Impossible Task Warm-up'),
#  (486, 6, 'Inferential Reasoning Game'),
#  (488, 6, 'Inferential Reasoning Warm-up'),
#  (637, 6, 'Memory versus Pointing'),
#  (602, 6, 'Memory versus Smell'),
#  (71, 6, 'Navigation Game'),
#  (79, 6, 'Navigation Learning'),
#  (103, 6, 'Navigation Warm-up'),
#  (38, 6, 'Numerosity Warm-Up'),
#  (675, 6, 'One Cup Warm-up'),
#  (370, 6, 'Physical Reasoning Game'),
#  (442, 6, 'Physical Reasoning Warm-up'),
#  (9, 6, 'Self Control Game'),
#  (6, 6, 'Shaker Game'),
#  (6, 6, 'Shaker Warm-Up'),
#  (8, 6, 'Shared Perspective'),
#  (8, 6, 'Slide'),
#  (7, 6, 'Smell Game'),
#  (6, 6, 'Stair Game'),
#  (9, 6, 'Switch'),
#  (1357, 6, 'Treat Warm-up'),
#  (713, 6, 'Turn Your Back'),
#  (663, 6, 'Two Cup Warm-up'),
#  (48, 6, 'Warm-Up'),
#  (958, 6, 'Watching'),
#  (683, 6, 'Watching - Part 2'),
#  (2794, 6, 'Yawn Game'),
#  (2959, 6, 'Yawn Warm-up'),
#  (29, 7, '1 vs 1 Game'),
#  (33, 7, '3 vs 1 Game'),
#  (59, 7, '5 vs 1 Game'),
#  (863, 7, 'Arm Pointing'),
#  (485, 7, 'Cover Your Eyes'),
#  (379, 7, 'Delayed Cup Game'),
#  (7, 7, 'Different Perspective'),
#  (10, 7, 'Expression Game'),
#  (1148, 7, 'Eye Contact Game'),
#  (1327, 7, 'Eye Contact Warm-up'),
#  (718, 7, 'Foot Pointing'),
#  (47, 7, 'Impossible Task Game'),
#  (48, 7, 'Impossible Task Warm-up'),
#  (398, 7, 'Inferential Reasoning Game'),
#  (416, 7, 'Inferential Reasoning Warm-up'),
#  (472, 7, 'Memory versus Pointing'),
#  (455, 7, 'Memory versus Smell'),
#  (67, 7, 'Navigation Game'),
#  (71, 7, 'Navigation Learning'),
#  (85, 7, 'Navigation Warm-up'),
#  (33, 7, 'Numerosity Warm-Up'),
#  (494, 7, 'One Cup Warm-up'),
#  (333, 7, 'Physical Reasoning Game'),
#  (379, 7, 'Physical Reasoning Warm-up'),
#  (10, 7, 'Self Control Game'),
#  (4, 7, 'Shaker Game'),
#  (5, 7, 'Shaker Warm-Up'),
#  (6, 7, 'Shared Perspective'),
#  (10, 7, 'Slide'),
#  (15, 7, 'Smell Game'),
#  (12, 7, 'Stair Game'),
#  (9, 7, 'Switch'),
#  (897, 7, 'Treat Warm-up'),
#  (499, 7, 'Turn Your Back'),
#  (491, 7, 'Two Cup Warm-up'),
#  (76, 7, 'Warm-Up'),
#  (638, 7, 'Watching'),
#  (471, 7, 'Watching - Part 2'),
#  (1715, 7, 'Yawn Game'),
#  (1848, 7, 'Yawn Warm-up'),
#  (16, 8, '1 vs 1 Game'),
#  (22, 8, '3 vs 1 Game'),
#  (36, 8, '5 vs 1 Game'),
#  (726, 8, 'Arm Pointing'),
#  (374, 8, 'Cover Your Eyes'),
#  (322, 8, 'Delayed Cup Game'),
#  (10, 8, 'Different Perspective'),
#  (10, 8, 'Expression Game'),
#  (1093, 8, 'Eye Contact Game'),
#  (1215, 8, 'Eye Contact Warm-up'),
#  (609, 8, 'Foot Pointing'),
#  (31, 8, 'Impossible Task Game'),
#  (32, 8, 'Impossible Task Warm-up'),
#  (320, 8, 'Inferential Reasoning Game'),
#  (326, 8, 'Inferential Reasoning Warm-up'),
#  (381, 8, 'Memory versus Pointing'),
#  (368, 8, 'Memory versus Smell'),
#  (39, 8, 'Navigation Game'),
#  (33, 8, 'Navigation Learning'),
#  (39, 8, 'Navigation Warm-up'),
#  (22, 8, 'Numerosity Warm-Up'),
#  (381, 8, 'One Cup Warm-up'),
#  (290, 8, 'Physical Reasoning Game'),
#  (318, 8, 'Physical Reasoning Warm-up'),
#  (12, 8, 'Self Control Game'),
#  (6, 8, 'Shaker Game'),
#  (6, 8, 'Shaker Warm-Up'),
#  (10, 8, 'Shared Perspective'),
#  (5, 8, 'Slide'),
#  (10, 8, 'Smell Game'),
#  (14, 8, 'Stair Game'),
#  (8, 8, 'Switch'),
#  (743, 8, 'Treat Warm-up'),
#  (384, 8, 'Turn Your Back'),
#  (383, 8, 'Two Cup Warm-up'),
#  (58, 8, 'Warm-Up'),
#  (471, 8, 'Watching'),
#  (373, 8, 'Watching - Part 2'),
#  (1479, 8, 'Yawn Game'),
#  (1655, 8, 'Yawn Warm-up'),
#  (23, 9, '1 vs 1 Game'),
#  (22, 9, '3 vs 1 Game'),
#  (44, 9, '5 vs 1 Game'),
#  (1185, 9, 'Arm Pointing'),
#  (536, 9, 'Cover Your Eyes'),
#  (379, 9, 'Delayed Cup Game'),
#  (12, 9, 'Different Perspective'),
#  (16, 9, 'Expression Game'),
#  (1618, 9, 'Eye Contact Game'),
#  (1905, 9, 'Eye Contact Warm-up'),
#  (936, 9, 'Foot Pointing'),
#  (30, 9, 'Impossible Task Game'),
#  (32, 9, 'Impossible Task Warm-up'),
#  (353, 9, 'Inferential Reasoning Game'),
#  (354, 9, 'Inferential Reasoning Warm-up'),
#  (514, 9, 'Memory versus Pointing'),
#  (474, 9, 'Memory versus Smell'),
#  (47, 9, 'Navigation Game'),
#  (49, 9, 'Navigation Learning'),
#  (53, 9, 'Navigation Warm-up'),
#  (22, 9, 'Numerosity Warm-Up'),
#  (542, 9, 'One Cup Warm-up'),
#  (274, 9, 'Physical Reasoning Game'),
#  (323, 9, 'Physical Reasoning Warm-up'),
#  (15, 9, 'Self Control Game'),
#  (11, 9, 'Shaker Game'),
#  (12, 9, 'Shaker Warm-Up'),
#  (12, 9, 'Shared Perspective'),
#  (17, 9, 'Slide'),
#  (15, 9, 'Smell Game'),
#  (17, 9, 'Stair Game'),
#  (13, 9, 'Switch'),
#  (1242, 9, 'Treat Warm-up'),
#  (556, 9, 'Turn Your Back'),
#  (515, 9, 'Two Cup Warm-up'),
#  (92, 9, 'Warm-Up'),
#  (758, 9, 'Watching'),
#  (531, 9, 'Watching - Part 2'),
#  (2495, 9, 'Yawn Game'),
#  (2701, 9, 'Yawn Warm-up'),
#  (26, 10, '1 vs 1 Game'),
#  (28, 10, '3 vs 1 Game'),
#  (53, 10, '5 vs 1 Game'),
#  (2361, 10, 'Arm Pointing'),
#  (1527, 10, 'Cover Your Eyes'),
#  (931, 10, 'Delayed Cup Game'),
#  (4, 10, 'Different Perspective'),
#  (1, 10, 'Expression Game'),
#  (3275, 10, 'Eye Contact Game'),
#  (3485, 10, 'Eye Contact Warm-up'),
#  (2135, 10, 'Foot Pointing'),
#  (35, 10, 'Impossible Task Game'),
#  (35, 10, 'Impossible Task Warm-up'),
#  (712, 10, 'Inferential Reasoning Game'),
#  (720, 10, 'Inferential Reasoning Warm-up'),
#  (1115, 10, 'Memory versus Pointing'),
#  (1014, 10, 'Memory versus Smell'),
#  (66, 10, 'Navigation Game'),
#  (67, 10, 'Navigation Learning'),
#  (72, 10, 'Navigation Warm-up'),
#  (29, 10, 'Numerosity Warm-Up'),
#  (1161, 10, 'One Cup Warm-up'),
#  (645, 10, 'Physical Reasoning Game'),
#  (674, 10, 'Physical Reasoning Warm-up'),
#  (7, 10, 'Self Control Game'),
#  (9, 10, 'Shaker Game'),
#  (10, 10, 'Shaker Warm-Up'),
#  (4, 10, 'Shared Perspective'),
#  (5, 10, 'Slide'),
#  (14, 10, 'Smell Game'),
#  (7, 10, 'Stair Game'),
#  (7, 10, 'Switch'),
#  (2449, 10, 'Treat Warm-up'),
#  (1582, 10, 'Turn Your Back'),
#  (1128, 10, 'Two Cup Warm-up'),
#  (61, 10, 'Warm-up'),
#  (1665, 10, 'Watching'),
#  (1456, 10, 'Watching - Part 2'),
#  (3873, 10, 'Yawn Game'),
#  (4178, 10, 'Yawn Warm-up'),
#  (15, 11, '1 vs 1 Game'),
#  (22, 11, '3 vs 1 Game'),
#  (40, 11, '5 vs 1 Game'),
#  (690, 11, 'Arm Pointing'),
#  (549, 11, 'Cover Your Eyes'),
#  (384, 11, 'Delayed Cup Game'),
#  (3, 11, 'Different Perspective'),
#  (9, 11, 'Expression Game'),
#  (848, 11, 'Eye Contact Game'),
#  (894, 11, 'Eye Contact Warm-up'),
#  (644, 11, 'Foot Pointing'),
#  (44, 11, 'Impossible Task Game'),
#  (45, 11, 'Impossible Task Warm-up'),
#  (326, 11, 'Inferential Reasoning Game'),
#  (339, 11, 'Inferential Reasoning Warm-up'),
#  (431, 11, 'Memory versus Pointing'),
#  (403, 11, 'Memory versus Smell'),
#  (41, 11, 'Navigation Game'),
#  (41, 11, 'Navigation Learning'),
#  (44, 11, 'Navigation Warm-up'),
#  (26, 11, 'Numerosity Warm-Up'),
#  (447, 11, 'One Cup Warm-up'),
#  (309, 11, 'Physical Reasoning Game'),
#  (315, 11, 'Physical Reasoning Warm-up'),
#  (14, 11, 'Self Control Game'),
#  (3, 11, 'Shaker Game'),
#  (3, 11, 'Shaker Warm-Up'),
#  (3, 11, 'Shared Perspective'),
#  (12, 11, 'Slide'),
#  (11, 11, 'Smell Game'),
#  (2, 11, 'Stair Game'),
#  (9, 11, 'Switch'),
#  (703, 11, 'Treat Warm-up'),
#  (556, 11, 'Turn Your Back'),
#  (437, 11, 'Two Cup Warm-up'),
#  (60, 11, 'Warm-Up'),
#  (566, 11, 'Watching'),
#  (524, 11, 'Watching - Part 2'),
#  (945, 11, 'Yawn Game'),
#  (1012, 11, 'Yawn Warm-up'),
#  (14, 12, '1 vs 1 Game'),
#  (42, 12, '3 vs 1 Game'),
#  (56, 12, '5 vs 1 Game'),
#  (624, 12, 'Arm Pointing'),
#  (414, 12, 'Cover Your Eyes'),
#  (271, 12, 'Delayed Cup Game'),
#  (9, 12, 'Different Perspective'),
#  (12, 12, 'Expression Game'),
#  (722, 12, 'Eye Contact Game'),
#  (798, 12, 'Eye Contact Warm-up'),
#  (528, 12, 'Foot Pointing'),
#  (45, 12, 'Impossible Task Game'),
#  (45, 12, 'Impossible Task Warm-up'),
#  (246, 12, 'Inferential Reasoning Game'),
#  (256, 12, 'Inferential Reasoning Warm-up'),
#  (343, 12, 'Memory versus Pointing'),
#  (324, 12, 'Memory versus Smell'),
#  (43, 12, 'Navigation Game'),
#  (45, 12, 'Navigation Learning'),
#  (47, 12, 'Navigation Warm-up'),
#  (42, 12, 'Numerosity Warm-Up'),
#  (367, 12, 'One Cup Warm-up'),
#  (220, 12, 'Physical Reasoning Game'),
#  (240, 12, 'Physical Reasoning Warm-up'),
#  (6, 12, 'Self Control Game'),
#  (1, 12, 'Shaker Game'),
#  (1, 12, 'Shaker Warm-Up'),
#  (7, 12, 'Shared Perspective'),
#  (6, 12, 'Slide'),
#  (13, 12, 'Smell Game'),
#  (8, 12, 'Stair Game'),
#  (6, 12, 'Switch'),
#  (624, 12, 'Treat Warm-up'),
#  (434, 12, 'Turn Your Back'),
#  (345, 12, 'Two Cup Warm-up'),
#  (53, 12, 'Warm-up'),
#  (516, 12, 'Watching'),
#  (405, 12, 'Watching - Part 2'),
#  (937, 12, 'Yawn Game'),
#  (1000, 12, 'Yawn Warm-up')]

# %%
# %%sql
# SELECT COUNT(cleaned_tests.created_at) AS completed_tests,
# CASE WHEN WEEKDAY(cleaned_tests.created_at)=0 THEN 'Monday'
#     WHEN WEEKDAY(cleaned_tests.created_at)=1 THEN 'Tuesday'
#     WHEN WEEKDAY(cleaned_tests.created_at)=2 THEN 'Wednesday'
#     WHEN WEEKDAY(cleaned_tests.created_at)=3 THEN 'Thursday'
#     WHEN WEEKDAY(cleaned_tests.created_at)=4 THEN 'Friday'
#     WHEN WEEKDAY(cleaned_tests.created_at)=5 THEN 'Saturday'
#     WHEN WEEKDAY(cleaned_tests.created_at)=6 THEN 'Sunday' END AS Weekday,
# cleaned_tests.test_name
# FROM
# (SELECT c.created_at, c.test_name, d.dog_guid
# FROM complete_tests c LEFT JOIN dogs d ON c.dog_guid=d.dog_guid
# WHERE d.dog_guid NOT IN
#     (SELECT DISTINCT(dog_guid) FROM dogs
#      WHERE (weight=190 AND breed='Shih Tzu') OR exclude=1)
#     AND c.dog_guid IS NOT NULL) AS cleaned_tests
# GROUP BY WEEKDAY(cleaned_tests.created_at), cleaned_tests.test_name
# ORDER BY WEEKDAY(cleaned_tests.created_at)
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 280 rows affected.
# [(28, 'Monday', '1 vs 1 Game'),
#  (34, 'Monday', '3 vs 1 Game'),
#  (65, 'Monday', '5 vs 1 Game'),
#  (1672, 'Monday', 'Arm Pointing'),
#  (979, 'Monday', 'Cover Your Eyes'),
#  (642, 'Monday', 'Delayed Cup Game'),
#  (12, 'Monday', 'Different Perspective'),
#  (12, 'Monday', 'Expression Game'),
#  (2351, 'Monday', 'Eye Contact Game'),
#  (2700, 'Monday', 'Eye Contact Warm-up'),
#  (1404, 'Monday', 'Foot Pointing'),
#  (66, 'Monday', 'Impossible Task Game'),
#  (66, 'Monday', 'Impossible Task Warm-up'),
#  (648, 'Monday', 'Inferential Reasoning Game'),
#  (641, 'Monday', 'Inferential Reasoning Warm-up'),
#  (838, 'Monday', 'Memory versus Pointing'),
#  (745, 'Monday', 'Memory versus Smell'),
#  (108, 'Monday', 'Navigation Game'),
#  (120, 'Monday', 'Navigation Learning'),
#  (155, 'Monday', 'Navigation Warm-up'),
#  (39, 'Monday', 'Numerosity Warm-Up'),
#  (872, 'Monday', 'One Cup Warm-up'),
#  (541, 'Monday', 'Physical Reasoning Game'),
#  (596, 'Monday', 'Physical Reasoning Warm-up'),
#  (18, 'Monday', 'Self Control Game'),
#  (15, 'Monday', 'Shaker Game'),
#  (15, 'Monday', 'Shaker Warm-Up'),
#  (8, 'Monday', 'Shared Perspective'),
#  (20, 'Monday', 'Slide'),
#  (24, 'Monday', 'Smell Game'),
#  (13, 'Monday', 'Stair Game'),
#  (19, 'Monday', 'Switch'),
#  (1702, 'Monday', 'Treat Warm-up'),
#  (999, 'Monday', 'Turn Your Back'),
#  (849, 'Monday', 'Two Cup Warm-up'),
#  (108, 'Monday', 'Warm-Up'),
#  (1209, 'Monday', 'Watching'),
#  (950, 'Monday', 'Watching - Part 2'),
#  (3368, 'Monday', 'Yawn Game'),
#  (3597, 'Monday', 'Yawn Warm-up'),
#  (35, 'Tuesday', '1 vs 1 Game'),
#  (45, 'Tuesday', '3 vs 1 Game'),
#  (76, 'Tuesday', '5 vs 1 Game'),
#  (1551, 'Tuesday', 'Arm Pointing'),
#  (935, 'Tuesday', 'Cover Your Eyes'),
#  (632, 'Tuesday', 'Delayed Cup Game'),
#  (13, 'Tuesday', 'Different Perspective'),
#  (9, 'Tuesday', 'Expression Game'),
#  (2080, 'Tuesday', 'Eye Contact Game'),
#  (2334, 'Tuesday', 'Eye Contact Warm-up'),
#  (1318, 'Tuesday', 'Foot Pointing'),
#  (73, 'Tuesday', 'Impossible Task Game'),
#  (76, 'Tuesday', 'Impossible Task Warm-up'),
#  (610, 'Tuesday', 'Inferential Reasoning Game'),
#  (619, 'Tuesday', 'Inferential Reasoning Warm-up'),
#  (784, 'Tuesday', 'Memory versus Pointing'),
#  (761, 'Tuesday', 'Memory versus Smell'),
#  (109, 'Tuesday', 'Navigation Game'),
#  (119, 'Tuesday', 'Navigation Learning'),
#  (152, 'Tuesday', 'Navigation Warm-up'),
#  (44, 'Tuesday', 'Numerosity Warm-Up'),
#  (820, 'Tuesday', 'One Cup Warm-up'),
#  (529, 'Tuesday', 'Physical Reasoning Game'),
#  (589, 'Tuesday', 'Physical Reasoning Warm-up'),
#  (6, 'Tuesday', 'Self Control Game'),
#  (9, 'Tuesday', 'Shaker Game'),
#  (9, 'Tuesday', 'Shaker Warm-Up'),
#  (14, 'Tuesday', 'Shared Perspective'),
#  (10, 'Tuesday', 'Slide'),
#  (21, 'Tuesday', 'Smell Game'),
#  (13, 'Tuesday', 'Stair Game'),
#  (11, 'Tuesday', 'Switch'),
#  (1614, 'Tuesday', 'Treat Warm-up'),
#  (968, 'Tuesday', 'Turn Your Back'),
#  (787, 'Tuesday', 'Two Cup Warm-up'),
#  (83, 'Tuesday', 'Warm-Up'),
#  (1142, 'Tuesday', 'Watching'),
#  (913, 'Tuesday', 'Watching - Part 2'),
#  (2824, 'Tuesday', 'Yawn Game'),
#  (3012, 'Tuesday', 'Yawn Warm-up'),
#  (31, 'Wednesday', '1 vs 1 Game'),
#  (38, 'Wednesday', '3 vs 1 Game'),
#  (65, 'Wednesday', '5 vs 1 Game'),
#  (1506, 'Wednesday', 'Arm Pointing'),
#  (962, 'Wednesday', 'Cover Your Eyes'),
#  (644, 'Wednesday', 'Delayed Cup Game'),
#  (10, 'Wednesday', 'Different Perspective'),
#  (15, 'Wednesday', 'Expression Game'),
#  (1860, 'Wednesday', 'Eye Contact Game'),
#  (2059, 'Wednesday', 'Eye Contact Warm-up'),
#  (1300, 'Wednesday', 'Foot Pointing'),
#  (60, 'Wednesday', 'Impossible Task Game'),
#  (63, 'Wednesday', 'Impossible Task Warm-up'),
#  (556, 'Wednesday', 'Inferential Reasoning Game'),
#  (573, 'Wednesday', 'Inferential Reasoning Warm-up'),
#  (805, 'Wednesday', 'Memory versus Pointing'),
#  (757, 'Wednesday', 'Memory versus Smell'),
#  (87, 'Wednesday', 'Navigation Game'),
#  (111, 'Wednesday', 'Navigation Learning'),
#  (149, 'Wednesday', 'Navigation Warm-up'),
#  (38, 'Wednesday', 'Numerosity Warm-Up'),
#  (851, 'Wednesday', 'One Cup Warm-up'),
#  (497, 'Wednesday', 'Physical Reasoning Game'),
#  (566, 'Wednesday', 'Physical Reasoning Warm-up'),
#  (18, 'Wednesday', 'Self Control Game'),
#  (7, 'Wednesday', 'Shaker Game'),
#  (7, 'Wednesday', 'Shaker Warm-Up'),
#  (10, 'Wednesday', 'Shared Perspective'),
#  (17, 'Wednesday', 'Slide'),
#  (18, 'Wednesday', 'Smell Game'),
#  (7, 'Wednesday', 'Stair Game'),
#  (15, 'Wednesday', 'Switch'),
#  (1553, 'Wednesday', 'Treat Warm-up'),
#  (993, 'Wednesday', 'Turn Your Back'),
#  (828, 'Wednesday', 'Two Cup Warm-up'),
#  (100, 'Wednesday', 'Warm-Up'),
#  (1161, 'Wednesday', 'Watching'),
#  (933, 'Wednesday', 'Watching - Part 2'),
#  (2511, 'Wednesday', 'Yawn Game'),
#  (2698, 'Wednesday', 'Yawn Warm-up'),
#  (32, 'Thursday', '1 vs 1 Game'),
#  (37, 'Thursday', '3 vs 1 Game'),
#  (69, 'Thursday', '5 vs 1 Game'),
#  (1304, 'Thursday', 'Arm Pointing'),
#  (825, 'Thursday', 'Cover Your Eyes'),
#  (619, 'Thursday', 'Delayed Cup Game'),
#  (8, 'Thursday', 'Different Perspective'),
#  (20, 'Thursday', 'Expression Game'),
#  (1713, 'Thursday', 'Eye Contact Game'),
#  (1922, 'Thursday', 'Eye Contact Warm-up'),
#  (1103, 'Thursday', 'Foot Pointing'),
#  (61, 'Thursday', 'Impossible Task Game'),
#  (53, 'Thursday', 'Impossible Task Warm-up'),
#  (532, 'Thursday', 'Inferential Reasoning Game'),
#  (554, 'Thursday', 'Inferential Reasoning Warm-up'),
#  (747, 'Thursday', 'Memory versus Pointing'),
#  (735, 'Thursday', 'Memory versus Smell'),
#  (90, 'Thursday', 'Navigation Game'),
#  (109, 'Thursday', 'Navigation Learning'),
#  (138, 'Thursday', 'Navigation Warm-up'),
#  (38, 'Thursday', 'Numerosity Warm-Up'),
#  (793, 'Thursday', 'One Cup Warm-up'),
#  (459, 'Thursday', 'Physical Reasoning Game'),
#  (507, 'Thursday', 'Physical Reasoning Warm-up'),
#  (9, 'Thursday', 'Self Control Game'),
#  (4, 'Thursday', 'Shaker Game'),
#  (4, 'Thursday', 'Shaker Warm-Up'),
#  (8, 'Thursday', 'Shared Perspective'),
#  (17, 'Thursday', 'Slide'),
#  (21, 'Thursday', 'Smell Game'),
#  (12, 'Thursday', 'Stair Game'),
#  (16, 'Thursday', 'Switch'),
#  (1336, 'Thursday', 'Treat Warm-up'),
#  (853, 'Thursday', 'Turn Your Back'),
#  (778, 'Thursday', 'Two Cup Warm-up'),
#  (104, 'Thursday', 'Warm-Up'),
#  (1040, 'Thursday', 'Watching'),
#  (815, 'Thursday', 'Watching - Part 2'),
#  (2339, 'Thursday', 'Yawn Game'),
#  (2518, 'Thursday', 'Yawn Warm-up'),
#  (27, 'Friday', '1 vs 1 Game'),
#  (57, 'Friday', '3 vs 1 Game'),
#  (83, 'Friday', '5 vs 1 Game'),
#  (1212, 'Friday', 'Arm Pointing'),
#  (808, 'Friday', 'Cover Your Eyes'),
#  (521, 'Friday', 'Delayed Cup Game'),
#  (7, 'Friday', 'Different Perspective'),
#  (15, 'Friday', 'Expression Game'),
#  (1634, 'Friday', 'Eye Contact Game'),
#  (1784, 'Friday', 'Eye Contact Warm-up'),
#  (1027, 'Friday', 'Foot Pointing'),
#  (55, 'Friday', 'Impossible Task Game'),
#  (62, 'Friday', 'Impossible Task Warm-up'),
#  (562, 'Friday', 'Inferential Reasoning Game'),
#  (576, 'Friday', 'Inferential Reasoning Warm-up'),
#  (661, 'Friday', 'Memory versus Pointing'),
#  (622, 'Friday', 'Memory versus Smell'),
#  (117, 'Friday', 'Navigation Game'),
#  (132, 'Friday', 'Navigation Learning'),
#  (164, 'Friday', 'Navigation Warm-up'),
#  (55, 'Friday', 'Numerosity Warm-Up'),
#  (708, 'Friday', 'One Cup Warm-up'),
#  (462, 'Friday', 'Physical Reasoning Game'),
#  (528, 'Friday', 'Physical Reasoning Warm-up'),
#  (18, 'Friday', 'Self Control Game'),
#  (11, 'Friday', 'Shaker Game'),
#  (12, 'Friday', 'Shaker Warm-Up'),
#  (7, 'Friday', 'Shared Perspective'),
#  (15, 'Friday', 'Slide'),
#  (22, 'Friday', 'Smell Game'),
#  (14, 'Friday', 'Stair Game'),
#  (13, 'Friday', 'Switch'),
#  (1236, 'Friday', 'Treat Warm-up'),
#  (814, 'Friday', 'Turn Your Back'),
#  (702, 'Friday', 'Two Cup Warm-up'),
#  (102, 'Friday', 'Warm-Up'),
#  (985, 'Friday', 'Watching'),
#  (772, 'Friday', 'Watching - Part 2'),
#  (2146, 'Friday', 'Yawn Game'),
#  (2276, 'Friday', 'Yawn Warm-up'),
#  (34, 'Saturday', '1 vs 1 Game'),
#  (60, 'Saturday', '3 vs 1 Game'),
#  (96, 'Saturday', '5 vs 1 Game'),
#  (1586, 'Saturday', 'Arm Pointing'),
#  (976, 'Saturday', 'Cover Your Eyes'),
#  (717, 'Saturday', 'Delayed Cup Game'),
#  (6, 'Saturday', 'Different Perspective'),
#  (14, 'Saturday', 'Expression Game'),
#  (1977, 'Saturday', 'Eye Contact Game'),
#  (2202, 'Saturday', 'Eye Contact Warm-up'),
#  (1336, 'Saturday', 'Foot Pointing'),
#  (78, 'Saturday', 'Impossible Task Game'),
#  (80, 'Saturday', 'Impossible Task Warm-up'),
#  (660, 'Saturday', 'Inferential Reasoning Game'),
#  (681, 'Saturday', 'Inferential Reasoning Warm-up'),
#  (918, 'Saturday', 'Memory versus Pointing'),
#  (840, 'Saturday', 'Memory versus Smell'),
#  (159, 'Saturday', 'Navigation Game'),
#  (178, 'Saturday', 'Navigation Learning'),
#  (206, 'Saturday', 'Navigation Warm-up'),
#  (66, 'Saturday', 'Numerosity Warm-Up'),
#  (932, 'Saturday', 'One Cup Warm-up'),
#  (560, 'Saturday', 'Physical Reasoning Game'),
#  (621, 'Saturday', 'Physical Reasoning Warm-up'),
#  (17, 'Saturday', 'Self Control Game'),
#  (6, 'Saturday', 'Shaker Game'),
#  (7, 'Saturday', 'Shaker Warm-Up'),
#  (5, 'Saturday', 'Shared Perspective'),
#  (24, 'Saturday', 'Slide'),
#  (22, 'Saturday', 'Smell Game'),
#  (16, 'Saturday', 'Stair Game'),
#  (21, 'Saturday', 'Switch'),
#  (1625, 'Saturday', 'Treat Warm-up'),
#  (969, 'Saturday', 'Turn Your Back'),
#  (935, 'Saturday', 'Two Cup Warm-up'),
#  (121, 'Saturday', 'Warm-Up'),
#  (1148, 'Saturday', 'Watching'),
#  (948, 'Saturday', 'Watching - Part 2'),
#  (2626, 'Saturday', 'Yawn Game'),
#  (2758, 'Saturday', 'Yawn Warm-up'),
#  (40, 'Sunday', '1 vs 1 Game'),
#  (65, 'Sunday', '3 vs 1 Game'),
#  (107, 'Sunday', '5 vs 1 Game'),
#  (1842, 'Sunday', 'Arm Pointing'),
#  (1144, 'Sunday', 'Cover Your Eyes'),
#  (955, 'Sunday', 'Delayed Cup Game'),
#  (23, 'Sunday', 'Different Perspective'),
#  (25, 'Sunday', 'Expression Game'),
#  (2183, 'Sunday', 'Eye Contact Game'),
#  (2432, 'Sunday', 'Eye Contact Warm-up'),
#  (1552, 'Sunday', 'Foot Pointing'),
#  (87, 'Sunday', 'Impossible Task Game'),
#  (86, 'Sunday', 'Impossible Task Warm-up'),
#  (875, 'Sunday', 'Inferential Reasoning Game'),
#  (911, 'Sunday', 'Inferential Reasoning Warm-up'),
#  (1128, 'Sunday', 'Memory versus Pointing'),
#  (1081, 'Sunday', 'Memory versus Smell'),
#  (184, 'Sunday', 'Navigation Game'),
#  (210, 'Sunday', 'Navigation Learning'),
#  (256, 'Sunday', 'Navigation Warm-up'),
#  (67, 'Sunday', 'Numerosity Warm-Up'),
#  (1145, 'Sunday', 'One Cup Warm-up'),
#  (737, 'Sunday', 'Physical Reasoning Game'),
#  (827, 'Sunday', 'Physical Reasoning Warm-up'),
#  (30, 'Sunday', 'Self Control Game'),
#  (17, 'Sunday', 'Shaker Game'),
#  (19, 'Sunday', 'Shaker Warm-Up'),
#  (21, 'Sunday', 'Shared Perspective'),
#  (26, 'Sunday', 'Slide'),
#  (25, 'Sunday', 'Smell Game'),
#  (27, 'Sunday', 'Stair Game'),
#  (26, 'Sunday', 'Switch'),
#  (1883, 'Sunday', 'Treat Warm-up'),
#  (1203, 'Sunday', 'Turn Your Back'),
#  (1129, 'Sunday', 'Two Cup Warm-up'),
#  (155, 'Sunday', 'Warm-Up'),
#  (1417, 'Sunday', 'Watching'),
#  (1110, 'Sunday', 'Watching - Part 2'),
#  (2930, 'Sunday', 'Yawn Game'),
#  (3111, 'Sunday', 'Yawn Warm-up')]

# %%
# %%sql
# # Where do most of Dognition's users live?
# SELECT COUNT(DISTINCT user_guid), country
# FROM users
# GROUP BY country
# ORDER BY COUNT(user_guid)
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 70 rows affected.
# [(1, 'TR'),
#  (1, 'HR'),
#  (1, 'BS'),
#  (1, 'LA'),
#  (1, 'DO'),
#  (1, 'TT'),
#  (1, 'LT'),
#  (1, 'UA'),
#  (1, 'LV'),
#  (1, 'ME'),
#  (1, 'IM'),
#  (1, 'BA'),
#  (1, 'IS'),
#  (1, 'CR'),
#  (1, 'NI'),
#  (1, 'GL'),
#  (1, 'SA'),
#  (1, 'CW'),
#  (1, 'BG'),
#  (1, 'CZ'),
#  (1, 'GU'),
#  (1, 'KY'),
#  (1, 'KZ'),
#  (1, 'AD'),
#  (2, 'PR'),
#  (2, 'VE'),
#  (2, 'JP'),
#  (2, 'BM'),
#  (2, 'SI'),
#  (2, 'PE'),
#  (3, 'PH'),
#  (3, 'AE'),
#  (3, 'RO'),
#  (3, 'HK'),
#  (3, 'PT'),
#  (4, 'AT'),
#  (3, 'CN'),
#  (4, 'IN'),
#  (3, 'CO'),
#  (4, 'RU'),
#  (4, 'GR'),
#  (5, 'PL'),
#  (5, 'AR'),
#  (5, 'HU'),
#  (8, 'CL'),
#  (9, 'IE'),
#  (9, 'SE'),
#  (11, 'IL'),
#  (10, 'FI'),
#  (10, 'BE'),
#  (14, 'EE'),
#  (12, 'MX'),
#  (13, 'ZA'),
#  (18, 'NL'),
#  (17, 'SG'),
#  (23, 'ES'),
#  (22, 'IT'),
#  (21, 'CH'),
#  (22, 'BR'),
#  (24, 'FR'),
#  (30, 'NO'),
#  (35, 'DK'),
#  (44, 'DE'),
#  (39, 'NZ'),
#  (135, 'GB'),
#  (148, 'AU'),
#  (501, 'CA'),
#  (5642, 'N/A'),
#  (9356, 'US'),
#  (16932, None)]

# %% [markdown]
# It looks like US has the most customers.
# Looking at US customers, when in the day do they complete the most tests?

# %%
# %%sql
# # Note that the time zones of U.S. users are different. For the numbers by
# # adjusted time zones, see the notebook on user retention.
#
# SELECT COUNT(c.created_at) AS count, HOUR(c.created_at) AS hour_n
# FROM complete_tests c
# LEFT JOIN dogs d ON c.dog_guid=d.dog_guid
# LEFT JOIN
#     (SELECT DISTINCT(user_guid) FROM users
#     WHERE NOT exclude =1
#     AND country='US'
#     AND user_guid NOT IN ('ce2258a6-7144-11e5-ba71-058fbc01cf0b','ce225842-7144-11e5-ba71-058fbc01cf0b'))
#     AS us_users
#     ON us_users.user_guid=d.user_guid
# WHERE (d.dog_guid NOT IN
#     (SELECT DISTINCT(dog_guid) FROM dogs
#      WHERE (weight=190 AND breed='Shih Tzu') OR exclude=1)
#     AND c.dog_guid IS NOT NULL)
# GROUP BY HOUR(c.created_at)
# ORDER BY HOUR(c.created_at);
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 24 rows affected.
# [(17263, 0),
#  (16278, 1),
#  (12544, 2),
#  (8412, 3),
#  (5068, 4),
#  (2468, 5),
#  (1433, 6),
#  (1102, 7),
#  (924, 8),
#  (1088, 9),
#  (1156, 10),
#  (1348, 11),
#  (2292, 12),
#  (3738, 13),
#  (5786, 14),
#  (7283, 15),
#  (8297, 16),
#  (9676, 17),
#  (10607, 18),
#  (11454, 19),
#  (11951, 20),
#  (11920, 21),
#  (12456, 22),
#  (14620, 23)]

# %%
# %%sql
# SELECT COUNT(c.test_name) AS count_test, COUNT(DISTINCT dog_breeds.dog_guid) AS count_dogs,
# COUNT(c.test_name)/COUNT(DISTINCT dog_breeds.dog_guid) AS avg_n_tests,
# dog_breeds.breed_group AS breed_group
# FROM complete_tests c
# JOIN
#     (SELECT DISTINCT dog_guid, breed_group
#      FROM dogs) AS dog_breeds
#     ON dog_breeds.dog_guid=c.dog_guid
# WHERE (dog_breeds.dog_guid NOT IN
#     (SELECT DISTINCT(dog_guid) FROM dogs
#      WHERE (weight=190 AND breed='Shih Tzu') OR exclude=1)
#     AND c.dog_guid IS NOT NULL)
#     AND breed_group IS NOT NULL
#     AND NOT breed_group = ''
# GROUP BY breed_group
# ORDER BY count_test DESC, avg_n_tests DESC
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 7 rows affected.
# [(27149, 2470, Decimal('10.9915'), 'Sporting'),
#  (19952, 1774, Decimal('11.2469'), 'Herding'),
#  (9659, 964, Decimal('10.0197'), 'Non-Sporting'),
#  (9024, 1025, Decimal('8.8039'), 'Toy'),
#  (8854, 865, Decimal('10.2358'), 'Working'),
#  (7748, 780, Decimal('9.9333'), 'Terrier'),
#  (5674, 564, Decimal('10.0603'), 'Hound')]

# %%
# %%sql
# SELECT COUNT(c.created_at) AS count_test, COUNT(dna_fixed.dog_guid) AS n_dogs,
#  COUNT(c.created_at)/COUNT(dna_fixed.dog_guid) AS avg_test_p_dog,
# dna_fixed.dna_tested AS DNA_tested
# FROM complete_tests c
# JOIN
#     (SELECT DISTINCT dog_guid, dna_tested, dog_fixed
#      FROM dogs
#     WHERE NOT ((weight=190 AND breed='Shih Tzu') OR exclude=1)
#     AND dog_guid IS NOT NULL) AS dna_fixed
#     ON c.dog_guid = dna_fixed.dog_guid
# GROUP BY dna_fixed.dna_tested
# ORDER BY count_test DESC
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 2 rows affected.
# [(3205, 3205, Decimal('1.0000'), 0), (498, 498, Decimal('1.0000'), 1)]

# %%
# %%sql
# SELECT COUNT(c.created_at) AS count_tests, COUNT(DISTINCT dna_fixed.dog_guid) AS count_dogs,
# COUNT(c.created_at)/COUNT(DISTINCT dna_fixed.dog_guid) AS avg_tests_p_dog,
# dna_fixed.dog_fixed AS neutered
# FROM complete_tests c
# JOIN
#     (SELECT DISTINCT dog_guid, dna_tested, dog_fixed
#      FROM dogs
#     WHERE NOT ((weight=190 AND breed='Shih Tzu') OR exclude=1)
#     AND dog_guid IS NOT NULL) AS dna_fixed
#     ON c.dog_guid = dna_fixed.dog_guid
# GROUP BY neutered
# ORDER BY count_tests DESC
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 2 rows affected.
# [(3249, 137, Decimal('23.7153'), 1), (454, 20, Decimal('22.7000'), 0)]

# %% [markdown]
# As can be seen, the datapoints regarding DNA tested or neutered are relatively small in comparison with the whole. There are no distinction between the average number of tests completed by dogs in these two groups, but there are more dogs that are neutered or not DNA-tested.
